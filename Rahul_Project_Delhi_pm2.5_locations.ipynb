# %%
dbutils.widgets.text("api_key", "", "Enter your OpenAQ API key here")

# %%
api_key = dbutils.widgets.get("api_key")
print("API Key starts with:", api_key[:4] + "..." if api_key else "No key entered")
# Out:
# API Key starts with: acf9...

# %%
# %pip install requests pandas
dbutils.library.restartPython()
# Out:
# Requirement already satisfied: requests in /databricks/python3/lib/python3.12/site-packages (2.32.2)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.12/site-packages (1.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests) (2024.6.2)
# Requirement already satisfied: numpy>=1.21.0 in /databricks/python3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import requests
import pandas as pd
import time

# %%
api_key = dbutils.widgets.get("api_key")
if not api_key:
    raise ValueError("⚠️ Please enter your OpenAQ API key in the widget above")

# %%
HEADERS = {
    "Accept": "application/json",
    "x-api-key": api_key
}

# %%
import requests, time

def fetch_india_locations(url, params, max_pages=20):
    results = []
    page = 1
    while page <= max_pages:
        params["page"] = page
        params["limit"] = 100
        res = requests.get(url, headers=HEADERS, params=params)

        if res.status_code == 429:
            print("Rate limit reached — waiting 30 seconds...")
            time.sleep(30)
            continue

        res.raise_for_status()
        data = res.json()
        batch = data.get("results", [])

        # Filter for India timezone
        india_batch = [loc for loc in batch if loc.get("timezone") == "Asia/Kolkata"]
        results.extend(india_batch)

        print(f"Fetched page {page}, batch size: {len(batch)}, India locations: {len(india_batch)}")

        if len(batch) < 100:
            break

        page += 1
        time.sleep(1)

    print(f"Total India locations found: {len(results)}")
    return results

# %%
BASE_URL = "https://api.openaq.org/v3"
url = f"{BASE_URL}/locations"
params = {"parameter": "pm25"}  # fetching PM2.5 now

india_locations = fetch_india_locations(url, params, max_pages=20)
# Out:
# Fetched page 1, batch size: 100, India locations: 7
# Fetched page 2, batch size: 100, India locations: 2
# Fetched page 3, batch size: 100, India locations: 4
# Fetched page 4, batch size: 100, India locations: 4
# Fetched page 5, batch size: 100, India locations: 0
# Fetched page 6, batch size: 100, India locations: 1
# Fetched page 7, batch size: 100, India locations: 4
# Fetched page 8, batch size: 100, India locations: 3
# Fetched page 9, batch size: 100, India locations: 1
# Fetched page 10, batch size: 100, India locations: 0
# Fetched page 11, batch size: 100, India locations: 0
# Fetched page 12, batch size: 100, India locations: 0
# Fetched page 13, batch size: 100, India locations: 0
# Fetched page 14, batch size: 100, India locations: 0
# Fetched page 15, batch size: 100, India locations: 0
# Fetched page 16, batch size: 100, India locations: 0
# Fetched page 17, batch size: 100, India locations: 0
# Fetched page 18, batch size: 100, India locations: 0
# Fetched page 19, batch size: 100, India locations: 0
# Fetched page 20, batch size: 100, India locations: 0
# Total India locations found: 26

# %%
#checking for all the found locations

import pandas as pd

# Convert the list of dictionaries to a DataFrame
india_locations_df = pd.DataFrame(india_locations)

# Display all columns for clarity
pd.set_option('display.max_columns', None)

# Show the DataFrame
display(india_locations_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>locality</th><th>timezone</th><th>country</th><th>owner</th><th>provider</th><th>isMobile</th><th>isMonitor</th><th>instruments</th><th>sensors</th><th>coordinates</th><th>licenses</th><th>bounds</th><th>distance</th><th>datetimeFirst</th><th>datetimeLast</th></tr></thead><tbody><tr><td>12</td><td>SPARTAN - IIT Kanpur</td><td>null</td><td>Asia/Kolkata</td><td>List(IN, 9, India)</td><td>List(4, Unknown Governmental Organization)</td><td>List(226, Spartan)</td><td>false</td><td>true</td><td>List(List(2, Government Monitor))</td><td>List(List(23, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)))</td><td>List(26.519, 80.233)</td><td>null</td><td>List(80.233, 26.519, 80.233, 26.519)</td><td>null</td><td>null</td><td>null</td></tr><tr><td>13</td><td>Delhi Technological University, Delhi - CPCB</td><td>null</td><td>Asia/Kolkata</td><td>List(IN, 9, India)</td><td>List(4, Unknown Governmental Organization)</td><td>List(168, CPCB)</td><td>false</td><td>true</td><td>List(List(2, Government Monitor))</td><td>List(List(13866, no2 µg/m³, List(NO₂ mass, 5, no2, µg/m³)), List(24, o3 µg/m³, List(O₃ mass, 3, o3, µg/m³)), List(13864, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)))</td><td>List(28.744, 77.12)</td><td>null</td><td>List(77.12, 28.744, 77.12, 28.744)</td><td>null</td><td>List(2016-11-03T00:30:00+05:30, 2016-11-02T19:00:00Z)</td><td>List(2018-02-22T09:30:00+05:30, 2018-02-22T04:00:00Z)</td></tr><tr><td>15</td><td>IGI Airport</td><td>null</td><td>Asia/Kolkata</td><td>List(IN, 9, India)</td><td>List(4, Unknown Governmental Organization)</td><td>List(168, CPCB)</td><td>false</td><td>true</td><td>List(List(2, Government Monitor))</td><td>List(List(27, co µg/m³, List(CO mass, 4, co, µg/m³)), List(28, no2 µg/m³, List(NO₂ mass, 5, no2, µg/m³)), List(29, o3 µg/m³, List(O₃ mass, 3, o3, µg/m³)), List(26, pm10 µg/m³, List(PM10, 1, pm10, µg/m³)), List(30, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)))</td><td>List(28.56, 77.094)</td><td>null</td><td>List(77.094, 28.56, 77.094, 28.56)</td><td>null</td><td>null</td><td>null</td></tr><tr><td>16</td><td>Civil Lines</td><td>null</td><td>Asia/Kolkata</td><td>List(IN, 9, India)</td><td>List(4, Unknown Governmental Organization)</td><td>List(168, CPCB)</td><td>false</td><td>true</td><td>List(List(2, Government Monitor))</td><td>List(List(33, co µg/m³, List(CO mass, 4, co, µg/m³)), List(32, no2 µg/m³, List(NO₂ mass, 5, no2, µg/m³)), List(31, pm10 µg/m³, List(PM10, 1, pm10, µg/m³)), List(34, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)))</td><td>List(28.6787, 77.2262)</td><td>null</td><td>List(77.2262, 28.6787, 77.2262, 28.6787)</td><td>null</td><td>null</td><td>null</td></tr><tr><td>17</td><td>R K Puram, Delhi - DPCC</td><td>null</td><td>Asia/Kolkata</td><td>List(IN, 9, India)</td><td>List(8524, Delhi Pollution Control Committee)</td><td>List(168, CPCB)</td><td>false</td><td>true</td><td>List(List(2, Government Monitor), List(2, Government Monitor))</td><td>List(List(12234782, co ppb, List(CO, 102, co, ppb)), List(392, co µg/m³, List(CO mass, 4, co, µg/m³)), List(12234783, no ppb, List(NO, 24, no, ppb)), List(12234784, no2 ppb, List(NO₂, 15, no2, ppb)), List(36, no2 µg/m³, List(NO₂ mass, 5, no2, µg/m³)), List(394, o3 µg/m³, List(O₃ mass, 3, o3, µg/m³)), List(12234785, o3 µg/m³, List(O₃ mass, 3, o3, µg/m³)), List(12234786, pm10 µg/m³, List(PM10, 1, pm10, µg/m³)), List(399, pm10 µg/m³, List(PM10, 1, pm10, µg/m³)), List(12234787, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)), List(35, pm25 µg/m³, List(PM2.5, 2, pm25, µg/m³)), List(12234788, relativehumidity %, List(RH, 98, relativehumidity, %)), List(12234789, so2 ppb, List(SO₂, 101, so2, ppb)), List(393, so2 µg/m³, List(SO₂ mass, 6, so2, µg/m³)), List(12234790, temperature c, List(Temperature (C), 100, temperature, c)))</td><td>List(28.563262, 77.186937)</td><td>null</td><td>List(77.186937, 28.563262, 77.186937, 28.563262)</td><td>null</td><td> ...

# %%
#fileterd the data using delhi's longitude and lattitude coordinates

DELHI_BOUNDS = {
    "lat_min": 28.40,
    "lat_max": 28.88,
    "lon_min": 76.84,
    "lon_max": 77.35
}

delhi_locations = [
    loc for loc in india_locations
    if "coordinates" in loc
    and DELHI_BOUNDS["lat_min"] <= loc["coordinates"]["latitude"] <= DELHI_BOUNDS["lat_max"]
    and DELHI_BOUNDS["lon_min"] <= loc["coordinates"]["longitude"] <= DELHI_BOUNDS["lon_max"]
]

print(f"Delhi locations found: {len(delhi_locations)}")
# Out:
# Delhi locations found: 10

# %%
import requests
import time
import pandas as pd

# 1. Extract Unique Location IDs (Assuming 'delhi_locations' is correctly populated)
delhi_location_ids = [loc.get('id') for loc in delhi_locations]
print(f"Unique Delhi Location IDs for query: {len(delhi_location_ids)}")

# --- Configuration (using existing variables) ---
# BASE_URL = "https://api.openaq.org/v3"
# HEADERS = { "Accept": "application/json", "x-api-key": api_key }


# --- STEP 1: Find PM2.5 Sensor IDs using /locations/{id} endpoint ---
pm25_sensor_ids = set()
total_locations = len(delhi_location_ids)

for i, loc_id in enumerate(delhi_location_ids):
    # Construct the correct URL path: /v3/locations/{location_id}
    LOCATION_DETAIL_URL = f"{BASE_URL}/locations/{loc_id}"
    
    print(f"Fetching sensor details for ID {loc_id} ({i+1}/{total_locations})...")
    
    try:
        res = requests.get(LOCATION_DETAIL_URL, headers=HEADERS)
        res.raise_for_status()
        data = res.json()
        
        if data.get("results"):
            location_details = data["results"][0]
            
            # 2. Iterate through sensors and filter for PM2.5 (Parameter ID 2)
            for sensor in location_details.get("sensors", []):
                param_id = sensor.get("parameter", {}).get("id")
                
                # PM2.5 has parameter ID 2 in OpenAQ
                if param_id == 2: 
                    # 3. Collect the sensor ID
                    pm25_sensor_ids.add(sensor.get('id'))
                    break # Found the PM2.5 sensor, move to the next location
            
    except requests.exceptions.RequestException as e:
        print(f"Error fetching location detail for ID {loc_id}: {e}")
        
    time.sleep(0.5) 

print(f"\nFound {len(pm25_sensor_ids)} unique PM2.5 sensor IDs.")
# Assuming pm25_sensor_ids is correctly populated from the previous successful step.

# --- Configuration (using existing variables) ---
# BASE_URL = "https://api.openaq.org/v3"
# HEADERS = { "Accept": "application/json", "x-api-key": api_key }


# Assuming pm25_sensor_ids is correctly populated from the successful Step 1.

# --- STEP 2: Query /latest endpoint and filter by Sensor ID (Correct Structure) ---
final_pm25_records = []
total_locations = len(delhi_location_ids)

for i, loc_id in enumerate(delhi_location_ids):
    # Construct the correct URL path: /v3/locations/{location_id}/latest
    LATEST_LOCATION_URL = f"{BASE_URL}/locations/{loc_id}/latest"
    
    print(f"Fetching ALL latest data for ID {loc_id} ({i+1}/{total_locations}) from {LATEST_LOCATION_URL}...")
    
    try:
        res = requests.get(LATEST_LOCATION_URL, headers=HEADERS)
        res.raise_for_status() 
        data = res.json()
        
        # 🐛 FIX: Iterate directly over the 'results' array, as each result IS a measurement
        for measurement in data.get("results", []):
            
            # 🐛 FIX: The Sensor ID is now accessed as a top-level key 'sensorsId' 
            # (as per the V3 documentation example)
            sensor_id = measurement.get("sensorsId") 
            
            # Filter to keep only latest info for sensor ids that exist in the pm25 sensor id list
            if sensor_id in pm25_sensor_ids:
                # This is a valid PM2.5 reading from a known Delhi sensor
                final_pm25_records.append({
                    "id": loc_id,
                    "pm25_value": measurement.get("value"),
                    "pm25_unit": "µg/m³", # Unit must be hardcoded or looked up since it's missing in /latest
                    "last_updated": measurement.get("datetime", {}).get("utc")
                })
                # Since the latest endpoint returns a single measurement per parameter, 
                # we can break after finding the first match for this location ID.
                break
        
    except requests.exceptions.RequestException as e:
        print(f"Error fetching latest data for ID {loc_id}: {e}")
        
    time.sleep(0.5) 

latest_pm25_df = pd.DataFrame(final_pm25_records)


# -------------------------------------------------------------
# CHECKPOINT: Display the data before the final merge
print("\n--- Fetched latest_pm25_df (Preview) ---")
display(latest_pm25_df) 
# -------------------------------------------------------------
# Out:
# Unique Delhi Location IDs for query: 10
# Fetching sensor details for ID 13 (1/10)...
# Fetching sensor details for ID 15 (2/10)...
# Fetching sensor details for ID 16 (3/10)...
# Fetching sensor details for ID 17 (4/10)...
# Fetching sensor details for ID 50 (5/10)...
# Fetching sensor details for ID 103 (6/10)...
# Fetching sensor details for ID 235 (7/10)...
# Fetching sensor details for ID 236 (8/10)...
# Fetching sensor details for ID 301 (9/10)...
# Fetching sensor details for ID 431 (10/10)...
#
# Found 10 unique PM2.5 sensor IDs.
# Fetching ALL latest data for ID 13 (1/10) from https://api.openaq.org/v3/locations/13/latest...
# Fetching ALL latest data for ID 15 (2/10) from https://api.openaq.org/v3/locations/15/latest...
# Fetching ALL latest data for ID 16 (3/10) from https://api.openaq.org/v3/locations/16/latest...
# Fetching ALL latest data for ID 17 (4/10) from https://api.openaq.org/v3/locations/17/latest...
# Fetching ALL latest data for ID 50 (5/10) from https://api.openaq.org/v3/locations/50/latest...
# Fetching ALL latest data for ID 103 (6/10) from https://api.openaq.org/v3/locations/103/latest...
# Fetching ALL latest data for ID 235 (7/10) from https://api.openaq.org/v3/locations/235/latest...
# Fetching ALL latest data for ID 236 (8/10) from https://api.openaq.org/v3/locations/236/latest...
# Fetching ALL latest data for ID 301 (9/10) from https://api.openaq.org/v3/locations/301/latest...
# Fetching ALL latest data for ID 431 (10/10) from https://api.openaq.org/v3/locations/431/latest...
#
# --- Fetched latest_pm25_df (Preview) ---
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>pm25_value</th><th>pm25_unit</th><th>last_updated</th></tr></thead><tbody><tr><td>13</td><td>451.0</td><td>µg/m³</td><td>2018-02-22T04:00:00Z</td></tr><tr><td>17</td><td>39.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td></tr><tr><td>50</td><td>37.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td></tr><tr><td>103</td><td>224.0</td><td>µg/m³</td><td>2018-02-22T03:45:00Z</td></tr><tr><td>235</td><td>51.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td></tr><tr><td>236</td><td>149.0</td><td>µg/m³</td><td>2018-02-21T21:15:00Z</td></tr><tr><td>301</td><td>152.9</td><td>µg/m³</td><td>2022-10-31T02:00:00Z</td></tr><tr><td>431</td><td>11.9</td><td>µg/m³</td><td>2018-02-22T02:45:00Z</td></tr></tbody></table></div>

# %%
# --- STEP 3: Final Merge with original Location Metadata ---

print("\n--- Final pm25_df ---")

# Create a base DataFrame from the successful location pull (delhi_locations) 
base_df = pd.DataFrame(delhi_locations)

# Correctly select and rename columns for the final DataFrame structure
base_df = base_df[['id', 'name', 'locality', 'coordinates']].drop_duplicates(subset=['id'])
base_df['latitude'] = base_df['coordinates'].apply(lambda x: x.get('latitude'))
base_df['longitude'] = base_df['coordinates'].apply(lambda x: x.get('longitude'))
base_df = base_df.rename(columns={'name': 'location', 'locality': 'city'})[['id', 'location', 'city', 'latitude', 'longitude']]


# Merge the base location info with the latest PM2.5 data
pm25_df = pd.merge(
    base_df,
    latest_pm25_df[['id', 'pm25_value', 'pm25_unit', 'last_updated']],
    on='id',
    how='left' 
)

display(pm25_df)
# Out:
# --- Final pm25_df ---
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>location</th><th>city</th><th>latitude</th><th>longitude</th><th>pm25_value</th><th>pm25_unit</th><th>last_updated</th></tr></thead><tbody><tr><td>13</td><td>Delhi Technological University, Delhi - CPCB</td><td>null</td><td>28.744</td><td>77.12</td><td>451.0</td><td>µg/m³</td><td>2018-02-22T04:00:00Z</td></tr><tr><td>15</td><td>IGI Airport</td><td>null</td><td>28.56</td><td>77.094</td><td>null</td><td>null</td><td>null</td></tr><tr><td>16</td><td>Civil Lines</td><td>null</td><td>28.6787</td><td>77.2262</td><td>null</td><td>null</td><td>null</td></tr><tr><td>17</td><td>R K Puram, Delhi - DPCC</td><td>null</td><td>28.563262</td><td>77.186937</td><td>39.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td></tr><tr><td>50</td><td>Punjabi Bagh, Delhi - DPCC</td><td>null</td><td>28.674045</td><td>77.131023</td><td>37.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td></tr><tr><td>103</td><td>Income Tax Office, Delhi - CPCB</td><td>null</td><td>28.623499999999996</td><td>77.2494</td><td>224.0</td><td>µg/m³</td><td>2018-02-22T03:45:00Z</td></tr><tr><td>235</td><td>Anand Vihar, New Delhi - DPCC</td><td>null</td><td>28.646835</td><td>77.316032</td><td>51.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td></tr><tr><td>236</td><td>Mandir Marg, Delhi - DPCC</td><td>null</td><td>28.6341</td><td>77.2005</td><td>149.0</td><td>µg/m³</td><td>2018-02-21T21:15:00Z</td></tr><tr><td>301</td><td>Vikas Sadan, Gurugram - HSPCB</td><td>null</td><td>28.4501238</td><td>77.0263051</td><td>152.9</td><td>µg/m³</td><td>2022-10-31T02:00:00Z</td></tr><tr><td>431</td><td>IHBAS, Delhi - CPCB</td><td>null</td><td>28.6821</td><td>77.305</td><td>11.9</td><td>µg/m³</td><td>2018-02-22T02:45:00Z</td></tr></tbody></table></div>

# %%
import pandas as pd

DANGER_LIMIT = 60  # WHO 24h guideline for PM2.5

pm25_df["danger_status"] = pm25_df["pm25_value"].apply(
    lambda x: "Cannot be determined" if pd.isnull(x)
    else ("Dangerous" if x > DANGER_LIMIT else "Safe")
)

display(pm25_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>location</th><th>city</th><th>latitude</th><th>longitude</th><th>pm25_value</th><th>pm25_unit</th><th>last_updated</th><th>danger_status</th></tr></thead><tbody><tr><td>13</td><td>Delhi Technological University, Delhi - CPCB</td><td>null</td><td>28.744</td><td>77.12</td><td>451.0</td><td>µg/m³</td><td>2018-02-22T04:00:00Z</td><td>Dangerous</td></tr><tr><td>15</td><td>IGI Airport</td><td>null</td><td>28.56</td><td>77.094</td><td>null</td><td>null</td><td>null</td><td>Cannot be determined</td></tr><tr><td>16</td><td>Civil Lines</td><td>null</td><td>28.6787</td><td>77.2262</td><td>null</td><td>null</td><td>null</td><td>Cannot be determined</td></tr><tr><td>17</td><td>R K Puram, Delhi - DPCC</td><td>null</td><td>28.563262</td><td>77.186937</td><td>39.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td><td>Safe</td></tr><tr><td>50</td><td>Punjabi Bagh, Delhi - DPCC</td><td>null</td><td>28.674045</td><td>77.131023</td><td>37.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td><td>Safe</td></tr><tr><td>103</td><td>Income Tax Office, Delhi - CPCB</td><td>null</td><td>28.623499999999996</td><td>77.2494</td><td>224.0</td><td>µg/m³</td><td>2018-02-22T03:45:00Z</td><td>Dangerous</td></tr><tr><td>235</td><td>Anand Vihar, New Delhi - DPCC</td><td>null</td><td>28.646835</td><td>77.316032</td><td>51.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td><td>Safe</td></tr><tr><td>236</td><td>Mandir Marg, Delhi - DPCC</td><td>null</td><td>28.6341</td><td>77.2005</td><td>149.0</td><td>µg/m³</td><td>2018-02-21T21:15:00Z</td><td>Dangerous</td></tr><tr><td>301</td><td>Vikas Sadan, Gurugram - HSPCB</td><td>null</td><td>28.4501238</td><td>77.0263051</td><td>152.9</td><td>µg/m³</td><td>2022-10-31T02:00:00Z</td><td>Dangerous</td></tr><tr><td>431</td><td>IHBAS, Delhi - CPCB</td><td>null</td><td>28.6821</td><td>77.305</td><td>11.9</td><td>µg/m³</td><td>2018-02-22T02:45:00Z</td><td>Safe</td></tr></tbody></table></div>

# %%
not_safe_df = pm25_df[pm25_df["danger_status"] == "Dangerous"]

display(not_safe_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>location</th><th>city</th><th>latitude</th><th>longitude</th><th>pm25_value</th><th>pm25_unit</th><th>last_updated</th><th>danger_status</th></tr></thead><tbody><tr><td>13</td><td>Delhi Technological University, Delhi - CPCB</td><td>null</td><td>28.744</td><td>77.12</td><td>451.0</td><td>µg/m³</td><td>2018-02-22T04:00:00Z</td><td>Dangerous</td></tr><tr><td>103</td><td>Income Tax Office, Delhi - CPCB</td><td>null</td><td>28.623499999999996</td><td>77.2494</td><td>224.0</td><td>µg/m³</td><td>2018-02-22T03:45:00Z</td><td>Dangerous</td></tr><tr><td>236</td><td>Mandir Marg, Delhi - DPCC</td><td>null</td><td>28.6341</td><td>77.2005</td><td>149.0</td><td>µg/m³</td><td>2018-02-21T21:15:00Z</td><td>Dangerous</td></tr><tr><td>301</td><td>Vikas Sadan, Gurugram - HSPCB</td><td>null</td><td>28.4501238</td><td>77.0263051</td><td>152.9</td><td>µg/m³</td><td>2022-10-31T02:00:00Z</td><td>Dangerous</td></tr></tbody></table></div>

# %%
safe_df = pm25_df[pm25_df["danger_status"] == "Safe"]
display(safe_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>location</th><th>city</th><th>latitude</th><th>longitude</th><th>pm25_value</th><th>pm25_unit</th><th>last_updated</th><th>danger_status</th></tr></thead><tbody><tr><td>17</td><td>R K Puram, Delhi - DPCC</td><td>null</td><td>28.563262</td><td>77.186937</td><td>39.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td><td>Safe</td></tr><tr><td>50</td><td>Punjabi Bagh, Delhi - DPCC</td><td>null</td><td>28.674045</td><td>77.131023</td><td>37.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td><td>Safe</td></tr><tr><td>235</td><td>Anand Vihar, New Delhi - DPCC</td><td>null</td><td>28.646835</td><td>77.316032</td><td>51.0</td><td>µg/m³</td><td>2025-10-06T06:30:00Z</td><td>Safe</td></tr><tr><td>431</td><td>IHBAS, Delhi - CPCB</td><td>null</td><td>28.6821</td><td>77.305</td><td>11.9</td><td>µg/m³</td><td>2018-02-22T02:45:00Z</td><td>Safe</td></tr></tbody></table></div>

# %%
undetermined_df = pm25_df[pm25_df["danger_status"] == "Cannot be determined"]
display(undetermined_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>location</th><th>city</th><th>latitude</th><th>longitude</th><th>pm25_value</th><th>pm25_unit</th><th>last_updated</th><th>danger_status</th></tr></thead><tbody><tr><td>15</td><td>IGI Airport</td><td>null</td><td>28.56</td><td>77.094</td><td>null</td><td>null</td><td>null</td><td>Cannot be determined</td></tr><tr><td>16</td><td>Civil Lines</td><td>null</td><td>28.6787</td><td>77.2262</td><td>null</td><td>null</td><td>null</td><td>Cannot be determined</td></tr></tbody></table></div>
